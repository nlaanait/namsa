# %% [markdown]
# @author: N. Laanait
# @email: laanaitn@ornl.gov
# @date: 10/13/2018

# %% [markdown]
# ## Multi-Slice Simulation of Si (111) with pure GPU code

# %% [markdown]
# Notes:
# 1. Running the code interactively could generate cuda errors for large # of probes (> 512) --> Use a python script for large simulations.
# 2. Some of the plots could take time to display.

# %%
from namsa import SupercellBuilder, MSAGPU
from namsa.utils import imageTile
import numpy as np
import matplotlib.pyplot as plt
from time import time

# %% [markdown]
# #### Build Si(111) supercell from cif

# %%
sp = SupercellBuilder('XYZ_files/Si.cif')
z_dir = np.array([1,1,1])
y_dir = np.array([1,0,0])
sp.transform_unit_cell()
sp.make_orthogonal_supercell(supercell_size=np.array([4*34.6,4*34.6,489.0]),
                             projec_1=y_dir, projec_2=z_dir)

# %% [markdown]
# #### Setup scattering

# %%
en = 100 # keV
semi_angle= 4e-3 # radians
max_ang = 200e-3
msa = MSAGPU(en, semi_angle, sp.supercell_sites, sampling=np.array([1024,1024]), 
          verbose=True, debug=False)
# Out:
# Simulation Parameters:
# Supercell dimensions xyz:[138.39 137.98 486.43] (Å)
# Real, Reciprocal space pixel sizes:[0.14 0.13] Å, [0.01 0.01] 1/Å
# Max angle: 0.27 (rad)
# Sampling in real and reciprocal space: [1024 1024] pixels,
# Thermal Effects: True

# %% [markdown]
# #### Calculate Atomic potentials

# %%
msa.calc_atomic_potentials()

# %% [markdown]
# ##### Plot

# %%
# Plot
itm = list(msa.cached_pots.keys())[0]
atom_pot = msa.cached_pots[itm]
fig, ax = plt.subplots()
ax.imshow(atom_pot**0.5, cmap='RdBu')
ax.set_title('Atom Potential for Z=%s'% itm)
# Out:
# Text(0.5,1,'Atom Potential for Z=14')

# %% [markdown]
# #### Build Potential Slices

# %%
slice_thickness = 3.15 # Å
msa.build_potential_slices(slice_thickness)
# Out:
# Built 154 potential slices with shape:(1024, 1024) pixels

# %% [markdown]
# ##### Plot

# %%
# Plot projected potential
projected_potential = np.imag(msa.potential_slices).sum(0)
fig, ax = plt.subplots(figsize=(8,8))
ax.imshow(projected_potential**0.25, cmap='jet')
ax.set_title('Projected Potential')
# Out:
# Text(0.5,1,'Projected Potential')

# %% [markdown]
# #### Build Electron Probe Wavefunction

# %%
aberration_params = {'C1':0., 'C3': 3.3e7, 'C5':0.0}
probe_params = {'smooth_apert': True, 'scherzer': False, 'apert_smooth': 60, 
                'aberration_dict':aberration_params, 'spherical_phase': True}
msa.build_probe(probe_dict=probe_params)
psi_x = msa.psi 
psi_k = msa.psi_k 
aperture = msa.apert
# Out:
# CUDA C/C++ Kernels compiled successfully

# %% [markdown]
# ##### Plot

# %%
fig,axes = plt.subplots(1,4,figsize=(24,12))
axes[0].imshow(np.abs(psi_k)**0.5,cmap='gnuplot2')
axes[0].set_title('Amplitude-$\Psi(k_x, k_y)$')
axes[1].imshow(np.angle(psi_k), cmap='gnuplot2', interpolation='bilinear')
axes[1].set_title('Phase-$\Psi(k_x, k_y)$')
axes[2].imshow(np.abs(psi_x)**0.25, cmap='gnuplot2')
axes[2].set_title('Amplitude-$\Psi(x, y)$')
axes[3].imshow(np.angle(psi_x), cmap='gnuplot2', interpolation='bilinear')
axes[3].set_title('Phase-$\Psi(k_x, k_y)$')
# Out:
# Text(0.5,1,'Phase-$\\Psi(k_x, k_y)$')

# %% [markdown]
# #### Generate probe positions

# %%
msa.generate_probe_positions(probe_step=np.array([2.5,2.5]), 
                             probe_range=np.array([[0.25,0.75],[0.25,0.75]]))

# %%
imp = np.imag(msa.potential_slices).sum(0)
fig,ax = plt.subplots(figsize=(6,6))
ax.imshow(imp**0.25,cmap='gray')
for pos in msa.probe_positions:
    img_coords = np.array(imp.shape)//2-pos*msa.sampling/msa.dims[:2]
    ax.plot(img_coords[1], img_coords[0],marker='o',markersize=4,color='r')
ax.set_title('Probe Positions')
# Out:
# Text(0.5,1,'Probe Positions')

# %% [markdown]
# ### Plan the simulation

# %%
msa.plan_simulation()
# Out:
# /home/nl7/anaconda3/lib/python3.6/site-packages/namsa-0.2-py3.6.egg/namsa/msa.py:324: UserWarning: Current fft plan is not valid. Decrease # probe positions!
#   warn('Current fft plan is not valid. Decrease # probe positions!')
# ---------------------------------------------------------------------------
# LogicError                                Traceback (most recent call last)
# <ipython-input-15-ad7fefea4123> in <module>()
# ----> 1 msa.plan_simulation()
#
# ~/anaconda3/lib/python3.6/site-packages/namsa-0.2-py3.6.egg/namsa/msa.py in plan_simulation(self, num_probes)
#     323         except:
#     324             warn('Current fft plan is not valid. Decrease # probe positions!')
# --> 325         free_mem, tot_mem = pycuda.driver.mem_get_info()
#     326         self.free_mem = free_mem/1024e6  # in GB
#     327         mem_alloc = num_probes * np.prod(self.sampling) * 8 / 1024e6 + self.potential_slices.nbytes / 1024e6
#
# LogicError: cuMemGetInfo failed: an illegal memory access was encountered

# %% [markdown]
# #### Propagate Probe Positions

# %%
msa.multislice()
# Out:
# CUDA C/C++ Kernels compiled successfully
# mem_alloc: 10.73152
# free_mem: 6.576832
# Simulation will propagate 578 probes simultaneously
# /home/nl7/anaconda3/lib/python3.6/site-packages/namsa-0.2-py3.6.egg/namsa/msa.py:335: UserWarning: Current fft plan is not valid. Decreasing # probe positions.
#   warn('Current fft plan is not valid. Decreasing # probe positions.')
# ---------------------------------------------------------------------------
# cufftExecFailed                           Traceback (most recent call last)
# <ipython-input-12-50420a2916e3> in <module>()
# ----> 1 msa.multislice()
#
# ~/anaconda3/lib/python3.6/site-packages/namsa-0.2-py3.6.egg/namsa/msa.py in multislice(self, bandwidth)
#     627         #pycuda.autoinit.context.synchronize()
#     628         psi_x_pos = pycuda.gpuarray.GPUArray(self.probes.shape, self.probes.dtype, allocator=psi_pos_d, gpudata=psi_pos_d)
# --> 629         cufft.ifft(psi_x_pos, psi_x_pos, fft_plan_probe, False)
#     630         #pycuda.autoinit.context.synchronize()
#     631         fftshift_func(psi_x_pos, block=block_3d, grid=grid_3d, shared=0)
#
# ~/anaconda3/lib/python3.6/site-packages/skcuda/fft.py in ifft(x_gpu, y_gpu, plan, scale)
#     298         return _fft(x_gpu, y_gpu, plan, cufft.CUFFT_INVERSE, y_gpu.size/plan.batch)
#     299     else:
# --> 300         return _fft(x_gpu, y_gpu, plan, cufft.CUFFT_INVERSE)
#     301
#     302 if __name__ == "__main__":
#
# ~/anaconda3/lib/python3.6/site-packages/skcuda/fft.py in _fft(x_gpu, y_gpu, plan, direction, scale)
#     193     if plan.fft_type in [cufft.CUFFT_C2C, cufft.CUFFT_Z2Z]:
#     194         plan.fft_func(plan.handle, int(x_gpu.gpudata), int(y_gpu.gpudata),
# --> 195                       direction)
#     196     else:
#     197         plan.fft_func(plan.handle, int(x_gpu.gpudata),
#
# ~/anaconda3/lib/python3.6/site-packages/skcuda/cufft.py in cufftExecC2C(plan, idata, odata, direction)
#     267     status = _libcufft.cufftExecC2C(plan, idata, odata,
#     268                                     direction)
# --> 269     cufftCheckStatus(status)
#     270
#     271 _libcufft.cufftExecR2C.restype = int
#
# ~/anaconda3/lib/python3.6/site-packages/skcuda/cufft.py in cufftCheckStatus(status)
#     108     if status != 0:
#     109         try:
# --> 110             raise cufftExceptions[status]
#     111         except KeyError:
#     112             raise cufftError
#
# cufftExecFailed:

# %% [markdown]
# ##### Plot

# %%
cbed = np.sum(np.abs(msa.probes)**2, axis=0)
# cbed = np.abs(msa.probes[0])**2
fig,ax = plt.subplots(figsize=(8,8))
cax = ax.imshow(cbed**0.25,cmap='gnuplot2')
plt.colorbar(cax)
